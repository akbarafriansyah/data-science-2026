# %% [markdown]
# <a href="https://colab.research.google.com/github/akbarafriansyah/data-science-2026/blob/main/Pertemuan1_Afriansyah_Akbar_250401020013.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ================================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ================================================================

# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")

# SEL 2: Variabel dan tipe data dasar
nama      = "Mahasiswa Informatika"     #String
angkatan  = 2024                        #Integer
ipk       = 3.75                        #Float
aktif     = True                        #Boolean

print(f"Nama      : {nama}")
print(f"Angkatan  : {angkatan}")
print(f"IPK       : {ipk}")
print(f"Aktif     : {aktif}")

# SEL 3: List dan Perulangan
tools = ["Phyton", "Google Colab", "Jupyter Notebook", "Github"]
print("\nTools Data Scince yang akan kita pelajari")
for i, tool in enumerate(tools, 1):
    print(f"  {i}.{tool}")

# SEL 4: Fungsi Sederhana
def perkenalan (nama, prodi, angkatan):
  """Fungsi untuk menampilkan perkenalan mahasiswa."""
  return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

  hasil = perkenalan("Budi Santoso", "Informatika", 2024)
  print(hasil)
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!
# Nama      : Mahasiswa Informatika
# Angkatan  : 2024
# IPK       : 3.75
# Aktif     : True
#
# Tools Data Scince yang akan kita pelajari
#   1.Phyton
#   2.Google Colab
#   3.Jupyter Notebook
#   4.Github
